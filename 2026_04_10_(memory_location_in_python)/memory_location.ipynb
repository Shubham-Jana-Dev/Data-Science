# %%
def memory_location_testing():
    x = 100
    y = 100
    z = 100
    k = 100
    print(x,id(x))
    print(y,id(y))
    print(z,id(z))
    print(k,id(k))
    print("--^v^--^v^--^v^--^v^--^v^--^v^--^v^--^v^--^v^-- # This is a demonstraion of the comparision operator... (* _ *) ")
    print("This portion is mostly use to solve the problem without the conditional statement...")
    print(x == y)
    print(x == z)
    print(x == k)
    print("--------------------")
    print(y == z)
    print(y == k)
    print("--------------------")
    print(z == k)
memory_location_testing()
# Out:
# 100 4345637888
# 100 4345637888
# 100 4345637888
# 100 4345637888
# --^v^--^v^--^v^--^v^--^v^--^v^--^v^--^v^--^v^-- # This is a demonstraion of the comparision operator... (* _ *)
# This portion is mostly use to solve the problem without the conditional statement...
# True
# True
# True
# --------------------
# True
# True
# --------------------
# True
