# %% [markdown]
# ### float.fromhex(s)
# * by the help of form_hex() function the user can convert hexadecimal string to coresponding floting point value.

# %%
print(float.fromhex("4F2A8C1B3D"))
print(float.fromhex("79E1A5F2C8"))
print(float.fromhex("DA8F2B4E6C"))
print(float.fromhex("79E1A5F2C8"))
print(float.fromhex("1C93B4E2A0"))
print(float.fromhex("5F8E2C9A3B"))
print(float.fromhex("eB2C4A1E8D6"))
print(float.fromhex("Fe2C8"))
print(float.fromhex("79E1A5FeaC8"))
print(float.fromhex("ABCDEF"))
# Out:
# 340016241469.0
# 523476792008.0
# 938704850540.0
# 523476792008.0
# 122737189536.0
# 410407180859.0
# 16160965912790.0
# 1041096.0
# 8375628720840.0
# 11259375.0

# %% [markdown]
# ### Float.hex()
# * By the help of float.hex() we can represent any floating point value to its coresponding hexadecimal string representation.

# %%
k = "4F2A8C1B3D"
y = float.fromhex(k)
print(y.hex())
# Out:
# 0x1.3caa306cf4000p+38

# %% [markdown]
# ### float.is_integer()
# * By the help of float.is_integer() the user can check the floating point value is start with integer decimal or not.

# %%
print((40.0).is_integer(),(4.5).is_integer(),(4.00000000000000099995).is_integer()) # True upto 15 '0's after the point '.'.
# Out:
# True False False

# %% [markdown]
# ### float._ _ abs _ _()
# * By the help of ._ _abs _ _() we can findout the absolute value of any floating point value.
# * The abs_ _() must be used over the nagative floating pointin value.

# %%
print((-8344.566666666666666666666666666666666666).__abs__())
# Out:
# 8344.566666666668

# %% [markdown]
# ### float._ _add _ _()
# * By the help of float. _ _add _ _() we can perform arithmatic addition operation on the floating point literals.

# %%
print(10.23.__add__(43.99))
# Out:
# 54.22

# %% [markdown]
# ### float._ _sub _ _()
# * By the help of float. _ _sub _ _() we can perform arithmatic subtaction operation on the floating point literals.

# %%
print(23.45.__sub__(90.78))
# Out:
# -67.33

# %% [markdown]
# ### float._ _mul _ _()
# * By the help of float. _ _mul _ _() we can perform arithmatic multiplication operation on the floating point literals.

# %%
print(34.55.__mul__(67.89))
# Out:
# 2345.5995

# %% [markdown]
# ### float._ _trudiv _ _()
# * By the help of float. _ _trudiv _ _() we can perform arithmatic divition operation on the floating point literals.

# %%
print(40.0.__truediv__(20.0))
# Out:
# 2.0

# %% [markdown]
# ### float._ _floordiv _ _()
# * By the help of float. _ _floordiv _ _() we can perform arithmatic floor divition operation on the floating point literals.

# %%
print(45.998.__floordiv__(3.78))
# Out:
# 12.0

# %% [markdown]
# ### float._ _mod _ _()
# * By the help of float. _ _mod _ _() we can perform arithmatic modulous operation on the floating point literals.

# %%
print(38.98.__mod__(32.77))
# Out:
# 6.209999999999994

# %% [markdown]
# ### float._ _pow _ _()
# * By the help of float. _ _add _ _() we can perform arithmatic exponantial operation on the floating point literals.

# %%
print(3.1.__pow__(3.1))
# Out:
# 33.35963197890903

# %% [markdown]
# ### float._ _round _ _()
# * By the help of float. _ _add _ _() we can round of a floating point literals.

# %%
print(34.667.__round__(2))
# Out:
# 34.67

# %%
print(23.67.conjugate()) 
print((34+54j).conjugate())
# Out:
# 23.677777777777777
# (34-54j)

# %%
print(float.fromhex("1EEE754"))
# Out:
# 32434004.0

# %%
num1 = 3.546
num2 = 45.67
print(num1/num2)
print((num1/num2).__round__(3))
# Out:
# 0.0776439675936063
# 0.078
