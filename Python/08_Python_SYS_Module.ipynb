# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham-Jana-Dev/Data-Science/blob/main/Python/08_Python_SYS_Module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
display(sys.version)
# Out:
# '3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0]'

# %%
for line in sys.stdin:
  if 'q' == line.rstrip():
    break
  display(f'Input: {line}')
display('Exit')
# Out:
# 'Exit'

# %%
j = int(input("Enter the string: "))
# Out:
# Enter the string: 66

# %%
sys.stdout.write('Shubham')
# Out:
# Shubham
# 7

# %%
import sys
def fun(*args):
  print(*args, file=sys.stderr)
fun("Shubham Jana")
# Out:
# Shubham Jana

# %%
n = len(sys.argv)
print("Total arguments passed:", n)
print("Name of Python script:", sys.argv[0])
print("Arguments passed:", end=" ")

for i in range(1, n):
  print(sys.argv[i], end=" ")
Sum = 0
for i in range(1, n):
  print(sys.argv[i], end=" ")
Sum = 0
for i in range(1,n):
  #Sum += int(sys.argv[i])
  pass
print(Sum)
# Out:
# Total arguments passed: 3
# Name of Python script: /usr/local/lib/python3.13/dist-packages/colab_kernel_launcher.py
# Arguments passed: -f /root/.local/share/jupyter/runtime/kernel-d898d3d1-1a56-478f-9be5-1103b71fbfdb.json -f /root/.local/share/jupyter/runtime/kernel-d898d3d1-1a56-478f-9be5-1103b71fbfdb.json 0

# %%
age = 17
if age < 18:
  sys.exit("Age is less than 18")
else:
  print("Age is not less than 18 :)")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Age is less than 18
# /usr/local/lib/python3.13/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
sys.apth = []
import pandas

# %%
import sys
sys.path = []
import pandas as pd
my_data = {
    "Name":["Shubham","Dipak","Danish","Rahul"],
    "Roll Number":[12,44,55,64]
}
df = pd.DataFrame(my_data)
print(df)
# Out:
#       Name  Roll Number
# 0  Shubham           12
# 1    Dipak           44
# 2   Danish           55
# 3    Rahul           64

# %%
print(sys.modules)
print(len(sys.modules))
# Out:
# {'sys': <module 'sys' (built-in)>, 'builtins': <module 'builtins' (built-in)>, '_frozen_importlib': <module '_frozen_importlib' (frozen)>, '_imp': <module '_imp' (built-in)>, '_thread': <module '_thread' (built-in)>, '_warnings': <module '_warnings' (built-in)>, '_weakref': <module '_weakref' (built-in)>, '_io': <module '_io' (built-in)>, 'marshal': <module 'marshal' (built-in)>, 'posix': <module 'posix' (built-in)>, '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>, 'time': <module 'time' (built-in)>, 'zipimport': <module 'zipimport' (frozen)>, '_codecs': <module '_codecs' (built-in)>, 'codecs': <module 'codecs' (frozen)>, 'encodings.aliases': <module 'encodings.aliases' from '/usr/lib/python3.13/encodings/aliases.py'>, 'encodings': <module 'encodings' from '/usr/lib/python3.13/encodings/__init__.py'>, 'encodings.utf_8': <module 'encodings.utf_8' from '/usr/lib/python3.13/encodings/utf_8.py'>, '_signal': <module '_signal' (built-in)>, '_abc': <module '_abc
# ...

# %%
# !pip install duckdb

# %%
print(sys.path)
print(len(sys.path))
# Out:
# []
# 0

# %%
a = "Shubham"
print(sys.getrefcount(a))
# Out:
# 4
