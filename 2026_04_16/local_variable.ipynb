# %%
class student:
    k = int(input("Enter the value of k: "))
    l = int(input("Enter the value of l: "))
    m = k + l
    print(m)
    def details(self):
        name = input("Enter the name: ")
        age = int(input("Enter the age: "))
        address = input("Enter the address: ")
        print(name)
        print(age)
        print(address)
s1 = student()
s1.details()
# Out:
# 76
# Shubham jana
# 19
# Kolkata

# %%
class student: 
    def __init__ (self,name,roll):
        self.name = name
        self.roll = roll
        print(name)
        print(roll)
ss = student("Shubham","324-00r-12")
# Out:
# Shubham
# 324-00r-12
