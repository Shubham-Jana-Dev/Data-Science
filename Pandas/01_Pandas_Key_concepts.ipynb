# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham-Jana-Dev/Data-Science/blob/main/Pandas/01_Pandas_Key_concepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
Data = {
    "Names":["Shubham","Rahul","Bikash","Dipak","Suman","Rudra","Milan","Sujoy"],
    "Marks":[98,98,78,67,66,90,89,92],
    "Adress":["Kolkata","Medinipur","Bakura","Birbhum","Malda","Jharagram","KuchBihar","Alipur"]
}

# %%
df = pd.DataFrame(Data)
display(df)
# Out:
#      Names  Marks     Adress
# 0  Shubham     98    Kolkata
# 1    Rahul     98  Medinipur
# 2   Bikash     78     Bakura
# 3    Dipak     67    Birbhum
# 4    Suman     66      Malda
# 5    Rudra     90  Jharagram
# 6    Milan     89  KuchBihar
# 7    Sujoy     92     Alipur

# %%
df.head(2)
# Out:
#      Names  Marks     Adress
# 0  Shubham     98    Kolkata
# 1    Rahul     98  Medinipur

# %%
df.tail(3)
# Out:
#    Names  Marks     Adress
# 5  Rudra     90  Jharagram
# 6  Milan     89  KuchBihar
# 7  Sujoy     92     Alipur

# %%
length = df["Marks"].count()
print(length)
# Out:
# 8

# %%
display(df["Marks"].count())
# Out:
# np.int64(8)

# %%
marks = np.array(df["Marks"])
display(marks)
# Out:
# array([98, 98, 78, 67, 66, 90, 89, 92])

# %%
display(marks*2)
# Out:
# array([196, 196, 156, 134, 132, 180, 178, 184])

# %%
display(np.average(marks))
# Out:
# np.float64(84.75)

# %%
display(np.mean(marks))
# Out:
# np.float64(84.75)

# %%
display(np.median(marks))
# Out:
# np.float64(89.5)

# %%
display(np.std(marks))
# Out:
# np.float64(12.04937757728589)

# %%
display(np.mod(marks,67))
# Out:
# array([31, 31, 11,  0, 66, 23, 22, 25])

# %%
# Just practice numpy a little bit 🤏 :)

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Names   8 non-null      object
#  1   Marks   8 non-null      int64
#  2   Adress  8 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 324.0+ bytes
# None
